# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/microsoft/VibeVoice-1.5B',
#  '/tencent/Hunyuan-MT-7B',
#  '/tencent/HunyuanWorld-Voyager',
#  '/meituan-longcat/LongCat-Flash-Chat',
#  '/google/embeddinggemma-300m',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/apple/fastvlm-webgpu',
#  '/spaces/zerogpu-aoti/wan2-2-fp8da-aoti-faster',
#  '/spaces/bytedance-research/USO',
#  '/spaces/multimodalart/Qwen-Image-Edit-Fast',
#  '/spaces',
#  '/datasets/HuggingFaceM4/FineVision',
#  '/datasets/data-agents/jupyter-agent-dataset',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/syncora/developer-productivity-simulated-behavioral-data',
#  '/datasets/facebook/recycling_the_web',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'home page', 'url': 'https://huggingface.co/'},
#   {'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://huggingface.co/contact'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# microsoft/VibeVoice-1.5B
# Updated
# 5 days ago
# •
# 203k
# •
# 1.5k
# tencent/Hunyuan-MT-7B
# Updated
# 2 days ago
# •
# 3.32k
# •
# 486
# tencent/HunyuanWorld-Voyager
# Updated
# 1 day ago
# •
# 256
# •
# 448
# meituan-longcat/LongCat-Flash-Chat
# Updated
# 5 days ago
# •
# 20k
# •
# 408
# google/embeddinggemma-300m
# Updated
# 1 day ago
# •
# 3.87k
# •
# 269
# Browse 1M+ models
# Spaces
# Running
# 12.8k
# 12.8k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 332
# 332
# FastVLM WebGPU
# 🍎
# Real-time video captioning powered by FastVLM
# Running
# on
# Zero
# MCP
# 739
# 739
# Wan2.2 14B Fast
# 🎥
# generate a video from an image with a text prompt
# Running
# on
# Zero
# 208
# 208
# USO FLUX
# ⚡
# Generate images by combining styles and subjects
# Running
# on
# Zero
# 287
# 287
# Qwen Image Edit Fast!
# ✒
# Fast 8 step inference of Qwen Image Edit
# Browse 400k+ applications
# Datasets
# HuggingFaceM4/FineVision
# Updated
# 1 day ago
# •
# 10.5k
# •
# 146
# data-agents/jupyter-agent-dataset
# Updated
# 1 day ago
# •
# 940
# •
# 89
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 43.8k
# •
# 8.98k
# syncora/developer-productivity-simulated-behavioral-data
# Updated
# 1 day ago
# •
# 1.01k
# •
# 131
# facebook/recycling_the_web
# Updated
# 9 days ago
# •
# 4.13k
# •
# 52
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 785 models
# •
# 3.99k followers
# AI at Meta
# Enterprise
# company
# •
# 2.22k models
# •
# 7.61k followers
# Amazon
# company
# •
# 20 models
# •
# 3.4k followers
# Google
# Enterprise
# company
# •
# 1.05k models
# •
# 27.7k followers
# Intel
# company
# •
# 239 models
# •
# 2.97k followers
# Microsoft
# company
# •
# 424 models
# •
# 15.1k followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 176 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 329 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 149,227
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,628
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,434
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,885
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 10,052
# Fast tokenizers optimized for research & production
# TRL
# 15,381
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,484
# State-of-the-art ML running directly in your browser
# smolagents
# 22,593
# Smol library to build great agents in Python
# PEFT
# 19,491
# Parameter-efficient finetuning for large language models
# Datasets
# 20,602
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,477
# Serve language models with TGI optimized toolkit
# Accelerate
# 9,099
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# about (Sergei)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Sergei
# about
# Follow
# Kalaipriya's profile picture
# jondelamothe's profile picture
# selvivincent's profile picture
# 5
# 					followers
# ·
# 0 following
# AI & ML interests
# None yet
# Organizations
# None yet
# models
# 0
# None public yet
# datasets
# 0
# None public yet
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Team & Enterprise Hub
# Scale your organization with the world’s leading AI platform
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Inference Providers
# Enable organization billing for Inference Providers, monitor usage with analytics, and manage spending limits.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Google
# Enterprise
# company
# •
# 1.05k models
# •
# 27.7k followers
# Shopify
# Enterprise
# company
# •
# 533 followers
# AMD
# Enterprise
# company
# •
# 172 models
# •
# 1.87k followers
# JetBrains
# Team
# company
# •
# 13 models
# •
# 685 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 329 followers
# ServiceNow
# Enterprise
# company
# •
# 2 models
# •
# 539 followers
# OpenAI
# Enterprise
# company
# •
# 35 models
# •
# 20k followers
# Toyota Research Institute
# Team
# company
# •
# 10 models
# •
# 141 followers
# IBM Granite
# Team
# company
# •
# 133 models
# •
# 2.32k followers
# BAIDU
# Team
# company
# •
# 25 models
# •
# 982 followers
# Technology Innovation Institute
# Team
# company
# •
# 107 models
# •
# 1.59k followers
# Novo Nordisk R&ED
# Team
# company
# •
# 61 followers
# HyperCLOVA X
# Team
# company
# •
# 4 models
# •
# 503 followers
# Liquid AI
# Team
# company
# •
# 13 models
# •
# 707 followers
# NVIDIA
# Enterprise
# +
# company
# •
# 487 models
# •
# 37k followers
# AI at Meta
# Enterprise
# company
# •
# 2.22k models
# •
# 7.61k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 270 followers
# Arm
# Enterprise
# company
# •
# 1 model
# •
# 268 followers
# Together
# Team
# company
# •
# 33 models
# •
# 679 followers
# Xsolla
# Enterprise
# company
# •
# 158 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 322 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 168 followers
# TNG Technology Consulting GmbH
# Team
# company
# •
# 5 models
# •
# 277 followers
# creditkarma
# Enterprise
# company
# •
# 80 followers
# Aledade Inc
# Enterprise
# +
# company
# •
# 72 followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 176 followers
# MiniMax
# Team
# company
# •
# 10 models
# •
# 1.7k followers
# LinkedIn
# Enterprise
# company
# •
# 76 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 59.8k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 314 followers
# Snowflake
# Enterprise
# company
# •
# 27 models
# •
# 596 followers
# Tenstorrent Inc.
# Team
# company
# •
# 227 followers
# Qwen
# Team
# company
# •
# 339 models
# •
# 47.8k followers
# PaloAltoNetworks
# Enterprise
# company
# •
# 199 followers
# Nutanix
# Enterprise
# company
# •
# 263 models
# •
# 131 followers
# Jusbrasil
# Team
# company
# •
# 106 followers
# FuriosaAI
# Team
# company
# •
# 18 models
# •
# 106 followers
# StepFun
# Team
# company
# •
# 25 models
# •
# 1.4k followers
# H2O.ai
# Team
# company
# •
# 71 models
# •
# 445 followers
# Roblox Corporation
# Enterprise
# company
# •
# 5 models
# •
# 280 followers
# HiddenLayer
# Team
# company
# •
# 1 model
# •
# 76 followers
# Fortis Games
# Enterprise
# company
# •
# 48 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Give your personal account or your organization the most advanced platform to build AI.
# PRO
# PRO Account
# Boost your personal HF experience
# Subscribe for
# $9
# per month
# Get PRO
# 10× private storage capacity
# 20× included inference credits
# 8× ZeroGPU quota and highest queue priority
# Spaces Dev Mode & ZeroGPU Spaces hosting
# Publish blog articles on your HF profile
# Dataset Viewer for private datasets
# Show your support with a Pro badge
# Team
# Instant setup for growing teams
# Subscribe for
# $20
# per user per month
# Get Team (via credit card)
# SSO and SAML support
# Choose data location with Storage Regions
# Detailed action reviews with Audit Logs
# Granular access control via Resource Groups
# Repository usage Analytics
# Set auth policies and default repository visibility
# Centralized token control and approvals
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# All organization members get ZeroGPU and Inference Providers PRO benefits
# Enterprise
# Custom onboarding and enterprise features
# Starting at
# $50
# per user per month
# Contact Sales
# All benefits from the Team plan
# Managed billing with annual commitments
# Legal and Compliance processes
# Personalized support
# Need support to adopt the HF Hub in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $2.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# ZeroGPU
# dynamic
# dynamic
# Nvidia H200
# 70 GB
# FREE
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# aws
# Intel Sapphire Rapids (overcommit)
# 16
# 32GB
# $0.01
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $2.50
# 2
# 160GB
# $5.00
# 4
# 320GB
# $10.00
# 8
# 640GB
# $20.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# Inference Providers
# : Get 20× included inference credits
# ZeroGPU
# : Get 8× usage quota and highest priority in queues
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Dataset Viewer
# : Activate and use it on private datasets
# Blog Articles
# : Publish articles on your HF profile
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Welcome EmbeddingGemma, Google's new efficient embedding model
# By
# tomaarsen
# September 4, 2025
# •
# 112
# Community Articles
# view all
# SAIR: Accelerating Pharma R&D with AI-Powered Structural Intelligence
# By
# SandboxAQ
# and 3 others
# •
# 3 days ago
# •
# 26
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 183
# Exploring Environments Hub: Your Language Model needs better (open) environments to learn
# By
# anakin87
# •
# 1 day ago
# •
# 12
# Theoretical Limitations of Embedding Models and Their Applications in Turkish: An In-Depth Look
# By
# nmmursit
# and 1 other
# •
# 1 day ago
# •
# 11
# 🥬 TinyLettuce: Efficient Hallucination Detection with 17–68M Encoders
# By
# adaamko
# and 1 other
# •
# 5 days ago
# •
# 9
# Introducing Marvis TTS: Real-Time Streaming Speech Synthesis
# By
# prince-canuma
# and 1 other
# •
# 9 days ago
# •
# 13
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 670
# Advertisement, Privacy, and Intimacy: Lessons from Social Media for Conversational AI
# By
# giadap
# and 1 other
# •
# 4 days ago
# •
# 7
# The Hacker's Guide to Building an AI Supercluster
# By
# codys12
# •
# 5 days ago
# •
# 7
# Hands-On with NatureLM-audio: A No-Code Demo
# By
# EarthSpeciesProject
# and 8 others
# •
# 1 day ago
# •
# 6
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 91
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 335
# Thinking Outside the Attention Box: Introducing Gated Associative Memory (GAM)
# By
# rishiraj
# •
# 3 days ago
# •
# 5
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 125
# Prefill and Decode for Concurrent Requests - Optimizing LLM Performance
# By
# tngtech
# •
# Apr 16
# •
# 40
# NVIDIA Releases 3 Million Sample Dataset for OCR, Visual Question Answering, and Captioning Tasks
# By
# nvidia
# and 4 others
# •
# 25 days ago
# •
# 72
# Turk-LettuceDetect: A Hallucination Detection Models for Turkish RAG Applications
# By
# nmmursit
# and 5 others
# •
# 8 days ago
# •
# 25
# AV1 for robotics AI streaming, training and storage.
# By
# haixuantao
# •
# 9 days ago
# •
# 12
# Building Conversational AI: A Deep Dive into Voice Agent Architectures and Best Practices
# By
# abdeljalilELmajjodi
# •
# 3 days ago
# •
# 4
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 168
# Make your ZeroGPU Spaces go brrr with PyTorch ahead-of-time compilation
# By
# cbensimon
# September 2, 2025
# •
# 39
# Generate Images with Claude and Hugging Face
# By
# evalstate
# August 19, 2025
# •
# 30
# From Zero to GPU: A Guide to Building and Scaling Production-Ready CUDA Kernels
# By
# drbh
# August 18, 2025
# •
# 52
# MCP for Research: How to Connect AI to Research Tools
# By
# dylanebert
# August 18, 2025
# •
# 44
# TextQuests: How Good are LLMs at Text-Based Video Games?
# By
# justinphan3110
# August 12, 2025
# guest
# •
# 30
# Introducing AI Sheets: a tool to work with datasets using open AI models!
# By
# dvilasuero
# August 8, 2025
# •
# 78
# Accelerate ND-Parallel: A Guide to Efficient Multi-GPU Training
# By
# siro1
# August 8, 2025
# •
# 58
# 🇵🇭 FilBench - Can LLMs Understand and Generate Filipino?
# By
# ljvmiranda921
# August 12, 2025
# •
# 15
# Vision Language Model Alignment in TRL ⚡️
# By
# sergiopaniego
# August 7, 2025
# •
# 78
# Welcome GPT OSS, the new open-source model family from OpenAI!
# By
# reach-vb
# August 5, 2025
# •
# 489
# Build an AI Shopping Assistant with Gradio MCP Servers
# By
# freddyaboulton
# July 31, 2025
# •
# 54
# Introducing Trackio: A Lightweight Experiment Tracking Library from Hugging Face
# By
# abidlabs
# July 29, 2025
# •
# 169
# Say hello to `hf`: a faster, friendlier Hugging Face CLI ✨
# By
# Wauplin
# July 25, 2025
# •
# 80
# Parquet Content-Defined Chunking
# By
# kszucs
# July 25, 2025
# •
# 62
# Previous
# 1
# 2
# 3
# ...
# 45
# Next
# Community Articles
# Sort:
# 		Trending
# SAIR: Accelerating Pharma R&D with AI-Powered Structural Intelligence
# By
# SandboxAQ
# and 3 others
# •
# 3 days ago
# •
# 26
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 183
# Exploring Environments Hub: Your Language Model needs better (open) environments to learn
# By
# anakin87
# •
# 1 day ago
# •
# 12
# Theoretical Limitations of Embedding Models and Their Applications in Turkish: An In-Depth Look
# By
# nmmursit
# and 1 other
# •
# 1 day ago
# •
# 11
# 🥬 TinyLettuce: Efficient Hallucination Detection with 17–68M Encoders
# By
# adaamko
# and 1 other
# •
# 5 days ago
# •
# 9
# Introducing Marvis TTS: Real-Time Streaming Speech Synthesis
# By
# prince-canuma
# and 1 other
# •
# 9 days ago
# •
# 13
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 670
# Advertisement, Privacy, and Intimacy: Lessons from Social Media for Conversational AI
# By
# giadap
# and 1 other
# •
# 4 days ago
# •
# 7
# The Hacker's Guide to Building an AI Supercluster
# By
# codys12
# •
# 5 days ago
# •
# 7
# Hands-On with NatureLM-audio: A No-Code Demo
# By
# EarthSpeciesProject
# and 8 others
# •
# 1 day ago
# •
# 6
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 91
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 335
# Thinking Outside the Attention Box: Introducing Gated Associative Memory (GAM)
# By
# rishiraj
# •
# 3 days ago
# •
# 5
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 125
# Prefill and Decode for Concurrent Requests - Optimizing LLM Performance
# By
# tngtech
# •
# Apr 16
# •
# 40
# NVIDIA Releases 3 Million Sample Dataset for OCR, Visual Question Answering, and Captioning Tasks
# By
# nvidia
# and 4 others
# •
# 25 days ago
# •
# 72
# Turk-LettuceDetect: A Hallucination Detection Models for Turkish RAG Applications
# By
# nmmursit
# and 5 others
# •
# 8 days ago
# •
# 25
# AV1 for robotics AI streaming, training and storage.
# By
# haixuantao
# •
# 9 days ago
# •
# 12
# Building Conversational AI: A Deep Dive into Voice Agent Architectures and Best Practices
# By
# abdeljalilELmajjodi
# •
# 3 days ago
# •
# 4
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 168
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# contact page
# Webpage Title:
# 404 – Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# 404
# Sorry, we can't find the page you are looking for.
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Request to Enable Hosted Inference API for my Public Model
# Models
# 1
# 6
# September 5, 2025
# AI Native Creation Is The Future
# Beginners
# 1
# 7
# September 5, 2025
# If You Had AGI—What Would You Actually Do With It?
# Research
# 6
# 35
# September 5, 2025
# AutoTrain LLM on Spaces: OMP_NUM_THREADS ValueError: '3500m' despite explicit ENV var setting
# 🤗AutoTrain
# 6
# 84
# September 5, 2025
# Curious About How AI Chat Models Achieve Deep Emotional Interaction
# Beginners
# 17
# 121
# September 5, 2025
# I can’t get Email confirmation link
# Site Feedback
# 82
# 9133
# September 5, 2025
# Space not listed, not visible
# Spaces
# 1
# 7
# September 5, 2025
# Multi-dimensional recursive and exponential NLP
# Research
# 1
# 20
# September 3, 2025
# API error for model sentence-transformers/all-MiniLM-L6-v2
# 🤗Transformers
# 8
# 35
# September 4, 2025
# Long term memory
# Beginners
# 4
# 47
# September 2, 2025
# HF Inference API: 503/504 Server Error
# Inference Endpoints on the Hub
# 4
# 295
# September 5, 2025
# "MandelMind: Fractal AI Consciousness Research (CC-0)"
# Research
# 57
# 209
# September 3, 2025
# System Crash while Running Local AI Models on MBA M1 – Need Help
# Beginners
# 1
# 7
# September 4, 2025
# 403ed from huggingfacehub
# 🤗Hub
# 1
# 6
# September 4, 2025
# Replicating a real world dev team using multiple AI models, which would you use?. Crazy idea? See inside for more detail
# Intermediate
# 6
# 48
# September 2, 2025
# Tasks that ar no supported by Supported_tasks
# Beginners
# 2
# 5
# September 5, 2025
# How Do AI Girlfriend Platforms Balance Text and Voice Training for Deep Emotional Connections?
# Beginners
# 2
# 39
# September 4, 2025
# Persistent Hugging Face API 401 Authentication Error from Base44 App (Token Validation Success, API Call Fail)
# Community Calls
# 1
# 15
# September 4, 2025
# AERIS – Cognitive Reasoning Layer for Dialectical Evaluation (Demo + Baseline)
# Spaces
# 7
# 124
# September 4, 2025
# Noticing shifts in AI Girlfriend platforms lately
# Beginners
# 1
# 21
# September 3, 2025
# Model Selection to convert Prompt to Json Object
# 🤗Transformers
# 1
# 3
# September 4, 2025
# AI for Low-Budget film making (an experiment)
# Research
# 2
# 452
# September 5, 2025
# Emergent LLM abilities between training sessions
# Beginners
# 5
# 76
# September 2, 2025
# Intermittent 504 Gateway Timeout on Inference API for mixedbread-ai/mxbai-embed-large-v1
# Inference Endpoints on the Hub
# 1
# 7
# September 4, 2025
# How to evaluate a tranied model?
# Models
# 3
# 16
# September 5, 2025
# Idea: AI-powered model recommendation for use cases
# Site Feedback
# 0
# 10
# September 3, 2025
# Dreaming - Types, function and implications
# Research
# 13
# 37
# September 1, 2025
# Seeking arXiv cs.AI Endorsement (Independent Researcher — Preprint on Emergent Identities in LLMs)
# Research
# 1
# 18
# September 2, 2025
# What are the best ways to get started with Hugging Face Transformers for NLP tasks?
# Beginners
# 1
# 21
# September 3, 2025
# How to load training_args
# Beginners
# 5
# 7378
# September 5, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# linkedin page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# LinkedIn respects your privacy
# LinkedIn and 3rd parties use essential and non-essential cookies to provide, secure, analyze and improve our Services, and to show you relevant ads (including
# professional and job ads
# ) on and off LinkedIn. Learn more in our
# Cookie Policy
# .
# Select Accept to consent or Reject to decline non-essential cookies for this use. You can update your choices at any time in your
# settings
# .
# Accept
# Reject
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Sign in
# Join now
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 615 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 10h
# Report this post
# The open source AI community is just made of people who are passionate and care about their work. So we thought it would be cool to share our favourite icons of the community with a fun award.
#
# Winners get free Hugging Face Pro Subscriptions, Merchandise, or compute credits for the hub.
#
# 🔗 Follow and nominate here:
# https://lnkd.in/ebEkqAeC
# This is a new initiative to recognise and celebrate the incredible work being done by community members. It's all about inspiring more collaboration and innovation in the world of machine learning and AI.
#
# They're highlighting contributors in four key areas:
# - model creators: building and sharing innovative and state-of-the-art models.
# - educators: sharing knowledge through posts, articles, demos, and events.
# - tool builders: creating the libraries, frameworks, and applications that we all use.
# - community champions: supporting and mentoring others in forums.
#
# Know someone who deserves recognition? Nominate them by opening a post in the Hugging Face community forum.
# 67
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Amélie Viallet
# Crafting interactions with data 🤗 Hugging Face | Building 'AI Sheets' the AI-powered spreadsheet
# 10h
# Report this post
# 🚨 Feature Alert! 🚨
# Ever wanted to:
#  ✨ Try multiple models to respond to the same prompt?
#  ✨ Compare different prompts for translation, classification, extraction, or summarization?
#
# With Column Duplication, you can do it very easily.
#
# Here’s how it works:
#
#  1️⃣ Import your dataset (or describe it, and we’ll generate one for you)
#  2️⃣ Add a column → write your prompt (or select from templates)
#  3️⃣  Select from 1000+ models, or use the default option.
#  4️⃣ Hit the Egg button to generate
#  5️⃣ Duplicate the column → tweak the prompt or switch the model
#
# Then you can compare results systematically and make an informed decision.
#
# Try it for free:
# https://lnkd.in/dymybmWf
# 18
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at Hugging Face 🤗 | Making AI work for libraries, archives, and their communities
# 12h
# Report this post
# Should museums trust GPT-5 to catalog their collections? Probably not...
#
# I tested GPT-5 on generating ICONCLASS (art history codes). For this landscape painting, it confidently assigned the code 25F4, which it told me was "Hills, slopes, rocks".
#
# That code actually means "reptiles"...
#
# A small specialised model that can run on minimal hardware and be trained in a few hours? Much better!
#
# The lesson for cultural heritage institutions (and many other domains!) is clear: specialised beats generalised for many domain-specific tasks.
#
# I just published a detailed guide on how I fine-tuned a vision model for ICONCLASS (a museum cataloging standard) using TRL +
# Hugging Face
# Jobs:
# https://lnkd.in/eJdyVHZB
# .
#
# Key takeaways:
#
# 🎯 4B parameter model outperforms GPT-5 on specialised museum metadata with minimal training.
# ⚡ Training took a few hours and <$10 (no local GPU needed!).
# 🛠️ TRL + HF Jobs made supervised fine-tuning of a VLM straightforward.
# 📚 Single UV script handles all dependencies.
#
# This was only possible because a suitable dataset was available on Hugging Face.
#
#  Imagine if every GLAM domain had specialised models:
#
# - Manuscript dating models trained on palaeography databases
# - Archive classification models trained on finding aids
# - Conservation models trained on condition reports
#
# The bottleneck isn't technology - it's data availability.
#
# To GLAM institutions: Consider sharing your collections on
# Hugging Face
# ! Your data could power the next generation of specialized heritage AI tools 🤗
#
# Check out the full tutorial:
# https://lnkd.in/eJdyVHZB
# .
#
# Try the model yourself:
# https://lnkd.in/eFauSE4x
# .
#
# Explore the training data:
# https://lnkd.in/eg5EC8HQ
# #DigitalHumanities
# #GLAM
# #AI
# 84
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 69,373 followers
# 1d
# Edited
# Report this post
# BOOM! Now you can deploy powerful MCP servers to Google Cloud in just a single command🔥
#
# > $ gradio deploy --provider gcloud
#
# Gradio offers key benefits for MCP server developers:
# > Built-in queue for scaling up to production workloads⚡
# > One-line CLI deployment to
# Hugging Face
# and
# Google Cloud
# > Free UI for humans-in-the-loop tests and cases
# > Authenticated access
# > Latency and performance data
#
# Detailed report:
# https://lnkd.in/gvUnFxKE
# Kudos to
# Steren Giannini
# and Abubakar Abid for spearheading the development!🐐
# 195
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 69,373 followers
# 1d
# Report this post
# 🚀🚀We've been cooking!
# Think: instant feedback, custom error messages, & validation that just works! Coming Soon to Gradio... 😜
# …more
# 27
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 1d
# Report this post
# September always means one thing: back to school. Even if your school days are far behind you, there's still a vibe to learn new things after summer.
#
# So we've got an intense (but FREE) program at
# Hugging Face
# over the next semester:
#
# - updated smol course on post training AI models.
# - brand new Hugging Face 101 for software engineers building AI.
# - expanded MCP course with the latest updates.
#
# We'll release new units every week so you should be able to follow along on all courses, or just pick what you need.
#
# First course is smol, so follow that org:
# https://lnkd.in/e4XA7zQd
# 320
# 12 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 69,373 followers
# 2d
# Report this post
# URGENT!! Gradio MCP servers now support all key primitives: Resources, Prompts, and Tools.
#
# Plus, you get real-time progress notifications, OpenAPI to MCP transformation, enhanced authentication, customizable tool descriptions, and performance metrics for all your MCP primitives.
# 118
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 3d
# Report this post
# ZeroGPU on 🤗
# Hugging Face
# Spaces enables anyone to build delightful ML demos, benefitting from powerful compute. But, due to its serverless nature, it is hard to optimize these demos.
#
# That CHANGES today 🪖
#
# Use AoT compilation to melt our ZeroGPU servers 🔥
#
# 💡 With AoT, we can export a compiled model once, save it, and later reload it instantly in any process, which is exactly what we need for ZeroGPU. This helps us reduce framework overhead and also eliminates cold-start timings typically incurred in just-in-time compilation.
#
# Additionally, the H200 hardware in ZeroGPUs makes it possible to use things like FlashAttention-3 and FP8 quantization. With AoT compilation + FA3, we were able to optimize the QwenImageEdit pipeline by 40% 🔥
#
# All of the details warrant a blog post for the community. So, we authored one 🤗
# Link in the comments ⬇️
#
# Brought to you by Charles B.,
# Linoy Tsaban
# ,
# Apolinário Passos (Poli)
# , and yours truly.
# 124
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Amélie Viallet
# Crafting interactions with data 🤗 Hugging Face | Building 'AI Sheets' the AI-powered spreadsheet
# 3d
# Report this post
# 🔥 The potential for expanding open datasets, adapting them to specific challenges, or improving them for entire communities is huge.
#
# For example, enriching the multilingual thinking dataset with a new column of generated content took me a few minutes.
#
# This open-source dataset has been downloaded over 20k times on the Hugging Face platform.
#
# I generate a new column that translates the model responses into the languages specified in another column.
#
# No formulas. Just a natural-language prompt.
#
# When I finished, I exported the enriched dataset to Hugging Face.
#
# 💫 That’s all it took.
#
# Try it:
# 👉
# https://lnkd.in/dymybmWf
# 29
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 4d
# Report this post
# BOOM! Microsoft just released an upgraded VibeVoice Large ~10B Text to Speech model - MIT licensed 🔥
#
# > Generate multi-speaker podcasts in minutes ⚡
# > Works blazingly fast on ZeroGPU with H200 (FREE)
#
# Try it out today on the space here:
# https://lnkd.in/gW_e2wTK
# and check out the model here:
# https://lnkd.in/gZyxgVbr
# 💥
# …more
# 592
# 26 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# NVIDIA
# Computer Hardware Manufacturing
# Santa Clara, CA
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nmicrosoft/VibeVoice-1.5B\nUpdated\n5 days ago\n•\n203k\n•\n1.5k\ntencent/Hunyuan-MT-7B\nUpdated\n2 days ago\n•\n3.32k\n•\n486\ntencent/HunyuanWorld-Voyager\nUpdated\n1 day ago\n•\n256\n•\n448\nmeituan-longcat/LongCat-Flash-Chat\nUpdated\n5 days ago\n•\n20k\n•\n408\ngoogle/embeddinggemma-300m\nUpdated\n1 day ago\n•\n3.87k\n•\n269\nBrowse 1M+ models\nSpaces\nRunning\n12.8k\n12.8k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\n332\n332\nFastVLM WebGPU\n🍎\nReal-time video captioning powered by FastVLM\nRunning\non\nZero\nMCP\n739\n739\nWan2.2 14B Fast\n🎥\ngenerate a video from an image with a text prompt\nRunning\non\nZero\n208\n208\nUSO FLUX\n⚡\nGenerate images by combining styles and subjects\nRunning\non\nZero\n287\n287\nQwen Image Edit Fast!\n✒\nFast 8 step inference of Qwen Image Edit\nBrowse 400k+ applications\nDatasets\nHuggingFaceM4/FineVision\nUpdated\n1 day ago\n•\n10.5k\n•\n146\ndata-agents/jupyter-agent-dataset\nUpdated\n1 day ago\n•\n940\n•\n89\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n43.8k\n•\n8.98k\nsyncora/developer-productivity-simulated-behavioral-data\nUpdated\n1 day ago\n•\n1.01k\n•\n131\nfacebook/recycling_the_web\nUpdated\n9 days ago\n•\n4.13k\n•\n52\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n785 models\n•\n3.99k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.22k models\n•\n7.61k followers\nAmazon\ncompany\n•\n20 models\n•\n3.4k followers\nGoogle\nEnterprise\ncompany\n•\n1.05k models\n•\n27.7k followers\nIntel\ncompany\n•\n239 models\n•\n2.97k followers\nMicrosoft\ncompany\n•\n424 models\n•\n15.1k followers\nGrammarly\nTeam\ncompany\n•\n11 models\n•\n176 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n329 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n149,227\nState-of-the-art AI models for PyTorch\nDiffusers\n30,628\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,434\nSafe way to store/distribute neural network weights\nHub Python Library\n2,885\nPython client to interact with the Hugging Face Hub\nTokenizers\n10,052\nFast tokenizers optimized for research & production\nTRL\n15,381\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,484\nState-of-the-art ML running directly in your browser\nsmolagents\n22,593\nSmol library to build great agents in Python\nPEFT\n19,491\nParameter-efficient finetuning for large language models ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company profile page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# Welcome to **Hugging Face**, the AI community building the future! At Hugging Face, we are dedicated to fostering collaboration among machine learning enthusiasts, developers, researchers, and organizations. Our platform not only supports the discovery of models, datasets, and applications but also encourages creativity and innovation in the world of artificial intelligence.
#
# ## About Us
# Hugging Face is more than just a company; it's a vibrant community that empowers users to create, share, and collaborate on state-of-the-art machine learning technology. Our mission is to make advances in AI accessible and beneficial for everyone. We offer a platform that enables public collaboration on countless machine learning models, datasets, and applications.
#
# ## Our Offerings
# ### **Models**
# With over **1 million models** to explore, including popular models like:
# - **microsoft/VibeVoice-1.5B**
# - **tencent/Hunyuan-MT-7B**
# - **google/embeddinggemma-300m**
#
# ### **Datasets**
# Access a vast library of over **250,000 datasets** tailored for various ML tasks. These resources are essential for developers looking to enhance their projects with rich data sources.
#
# ### **Spaces**
# Engage with **400,000+ applications** on our platform. This includes interactive demos and projects built using our powerful tools, which help visualize machine learning concepts in dynamic ways.
#
# ### **Enterprise Solutions**
# For organizations, we provide enterprise-grade solutions with robust features such as:
# - Team collaboration tools
# - Advanced security measures
# - Dedicated support
#
# Starting at just **$20/user/month**, our enterprise offerings are designed to help teams accelerate their ML initiatives securely and efficiently.
#
# ## Community Engagement
# We're proud to have over **50,000 organizations** leveraging Hugging Face for their AI needs, including industry leaders like Google, Microsoft, and Amazon.
#
# Join our community to engage in discussions, share insights, and contribute to a growing body of knowledge in AI and ML. With active participation, you can build your professional portfolio and network with like-minded individuals!
#
# ## Company Culture
# At Hugging Face, we believe in the power of collective growth and open-source collaboration. Our culture is defined by:
# - **Inclusivity:** Welcoming individuals from diverse backgrounds and disciplines.
# - **Innovation:** Encouraging creativity and experimentation.
# - **Support:** Fostering an environment where team members can thrive and contribute.
#
# ## Careers at Hugging Face
# We are always on the lookout for passionate individuals who share our vision. If you're enthusiastic about AI, research, and community engagement, we want to hear from you! Visit our [Careers page](https://huggingface.co/jobs) to explore current openings.
#
# ---
#
# Whether you're a budding ML enthusiast, an industry expert, or someone looking to enhance your team’s capabilities, Hugging Face offers the tools, resources, and community support you need to succeed in Artificial Intelligence.
#
# **Join us in building the future of AI!**
# Explore more at [Hugging Face](https://huggingface.co).
#
# ---
#
# For questions or inquiries, feel free to reach out to us via our [social platforms](https://huggingface.co/social). Let's connect!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## **About Us**
# Hugging Face is a vibrant community and platform dedicated to building the future of artificial intelligence (AI). We provide a collaborative environment for machine learning experts to innovate, share, and grow together. Our vast ecosystem encompasses over **1 million models**, **250,000 datasets**, and a thriving community bringing cutting-edge AI applications to life.
#
# ### **Our Mission**
# We aim to empower the machine learning community by providing accessible tools, resources, and opportunities for collaboration. At Hugging Face, we believe in the power of community-driven development to accelerate progress and democratize AI technology.
#
# ## **What We Offer**
# - **Models**: Access a vast library featuring a diverse range of machine learning models, including state-of-the-art solutions from organizations like **Google**, **Amazon**, and **Microsoft**.
# - **Datasets**: Discover thousands of datasets designed for various machine learning tasks, fostering better research and development.
# - **Spaces**: A platform to create, share, and experiment with AI applications collaboratively.
# - **Enterprise Solutions**: Tailored offerings for organizations requiring advanced capabilities, dedicated support, and enterprise-grade security.
#
# ## **Customer Base**
# More than **50,000 organizations** utilize Hugging Face's services, including major players like Facebook, Intel, and Grammarly. Our community is engaged through contributions and active participation in projects, making us a preferred solution for industry leaders and start-ups alike.
#
# ## **Company Culture**
# Hugging Face champions an inclusive and collaborative company culture, emphasizing openness and community engagement. Our team is dedicated to personal and professional growth, welcoming creativity and innovation from all members. We value diversity and strive to create an environment where every voice is heard.
#
# ## **Careers at Hugging Face**
# Join us in shaping the future of AI! We are always looking for passionate individuals to add to our dynamic team. Explore exciting career opportunities in engineering, data science, community engagement, and more. Visit our **Jobs** page to learn about our current openings and how you can contribute to our mission.
#
# ## **Get Started Today**
# Whether you're an individual looking to enhance your projects with AI, a business seeking scalable solutions, or a developer eager to join our team, Hugging Face has something for you.
#
# **Visit us at:** [Hugging Face](https://huggingface.co)
# **Connect with us on Social Media:** GitHub | Twitter | LinkedIn | Discord
#
# ---
#
# Together, let’s build the future of AI!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
